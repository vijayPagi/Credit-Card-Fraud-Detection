# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
style.use('fivethirtyeight')

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
print(df.describe())
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
print(df.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (284807, 31)

# %%
df = df.sample(frac= 0.3, random_state= 42)
print(df.shape)
# Out:
# (85442, 31)

# %%
df.hist(figsize= (30, 30))
plt.show()

# %% [markdown]
# Lets find the number fraud and correct transactions

# %%
fraud_trx = df[df['Class'] == 1]
crct_trx = df[df['Class'] == 0]

outlier_fraction = len(fraud_trx)/float(len(crct_trx))

print(outlier_fraction)

print('Fraudulent Cases: {}'.format(len(fraud_trx)))
print('valid Cases: {}'.format(len(crct_trx)))
# Out:
# 0.0015942606616181746
# Fraudulent Cases: 136
# valid Cases: 85306

# %% [markdown]
# Correlation Matrix for finding correlation between class and all the transactions

# %%
corr = df.corr()

fig = plt.figure(figsize= (12,9))

sns.heatmap(corr, vmax= .8, square=True)
plt.show()

# %%
columns = df.columns.tolist()

columns = [c for c in columns if c not in ["Class"]]

target = "Class"

X = df[columns]
Y = df[target]


print(X.shape)
print(Y.shape)
# Out:
# (85442, 30)
# (85442,)

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import SVC

# %%
rState = 42

classifiers = {"Isolation Forest": IsolationForest(max_samples= len(X), 
                                                   contamination= outlier_fraction,
                                                  random_state = rState),
              "Local Outlier Factor": LocalOutlierFactor(n_neighbors= 20,
                                                        contamination = outlier_fraction)}

# %%
n_outliers = len(fraud_trx)

for i, (clf_name, clf) in enumerate(classifiers.items()):
    if clf_name == "Local Outlier Factor":
        y_pred = clf.fit_predict(X)
        scores_pred = clf.negative_outlier_factor_
    else:
        clf.fit(X)
        scores_pred = clf.decision_function(X)
        y_pred = clf.predict(X)
        
    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1
    
    n_errors = (y_pred != Y).sum()
    
    print('{}: {}'.format(clf_name, n_errors))
    print(accuracy_score(Y, y_pred))
    print(classification_report(Y,y_pred))
# Out:
# Isolation Forest: 175
# 0.9979518269703425
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     85306
#           1       0.36      0.36      0.36       136
#
# avg / total       1.00      1.00      1.00     85442
#
# Local Outlier Factor: 271
# 0.9968282577655018
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     85306
#           1       0.01      0.01      0.01       136
#
# avg / total       1.00      1.00      1.00     85442

# %%
clsf = SVC()

# %%
clsf.fit(X,Y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_predict = clsf.predict(X)

# %%
y_predict[y_predict == 1] = 0
y_predict[y_predict == -1] = 1
    
n_errors = (y_predict != Y).sum()
    
print('{}: {}'.format(clsf, n_errors))
print(accuracy_score(Y, y_predict))
print(classification_report(Y,y_predict))
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False): 136
# 0.9984082769598089
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     85306
#           1       0.00      0.00      0.00       136
#
# avg / total       1.00      1.00      1.00     85442
# /Users/pagidoju/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
